# %%
from nilearn.datasets import fetch_haxby
from PIL import Image

haxby = fetch_haxby(subjects=[], fetch_stimuli=True)

stimuli = haxby.stimuli
for v in stimuli['cats']:
    out = Image.open(v)

    # show image
    out.show()
# Out:
# [get_dataset_dir] Dataset found in /home/akhil/nilearn_data/haxby2001
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400>
# ...
